# %% [markdown]
# # CWRU Bearing Fault Data - Data Preprocessing (divided by load)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import re
import scipy.io
import pickle
import math

# %% [markdown]
# ## 48k Drive-End Bearing Fault Data + Normal Baseline Data (48k)

# %% [markdown]
# ### Reading and spliting data by load and fault type

# %%
BASE_PATH = 'Data'
NORMAL_DATA_PATH = 'NormalBaselineData'
DRIVE_END_48K_DATA_PATH = '48kDriveEndBearingFaultData'

# %%
def load_data_for_motorload(load):
  data = []

  # Loading Normal Baseline Data for chosen motorload
  normal_dir = os.path.join(BASE_PATH, NORMAL_DATA_PATH)
  for filename in os.listdir(normal_dir):
    if filename.endswith(f"_{load}.mat"):
      filepath = os.path.join(normal_dir, filename)
      try:
        mat = scipy.io.loadmat(filepath)
        de_key = next((k for k in mat.keys() if re.match(r".*_DE_time$", k)), None)
        if de_key is None:
          print(f"No DE_time key found in {filepath}")
          continue
        signal = mat[de_key].squeeze()
        label = filename[:-4].rsplit('_', 1)[0]
        data.append({
          'signal': signal,
          'label': label,
          'load': load
        })
      except Exception as e:
        print(f"Error loading {filepath}: {e}")

  # Loading Drive End Bearing Fault Data
  fault_dir = os.path.join(BASE_PATH, DRIVE_END_48K_DATA_PATH)
  for subfolder in os.listdir(fault_dir):
    subfolder_path = os.path.join(fault_dir, subfolder)
    if not os.path.isdir(subfolder_path):
      continue
    for filename in os.listdir(subfolder_path):
      if filename.endswith(f"_{load}.mat"):
        filepath = os.path.join(subfolder_path, filename)
        try:
          mat = scipy.io.loadmat(filepath)
          print(filepath + "\n")
          de_key = next((k for k in mat.keys() if re.match(r".*_DE_time$", k)), None)
          if de_key is None:
            print(f"No DE_time key found in {filepath}")
            continue
          signal = mat[de_key].squeeze()
          label = filename[:-4].rsplit('_', 1)[0]
          data.append({
            'signal': signal,
            'label': label,
            'load': load
          })
        except Exception as e:
          print(f"Error loading {filepath}: {e}")

  return pd.DataFrame(data)

# %%
# Merging data for all motorloads data subsets
data = []
for load in range(4):
  df = load_data_for_motorload(load)
  data.append(df)

data = pd.concat(data, ignore_index=True)
# Out:
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B007_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B014_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B021_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOpposite@12.00/OR021@12_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOpposite@12.00/OR007@12_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOrthogonal@3.00/OR021@3_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOrthogonal@3.00/OR007@3_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR007_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR014_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR021_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR014@6_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR021@6_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR007@6_0.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B007_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B014_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B021_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOpposite@12.00/OR021@12_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOpposite@12.00/OR007@12_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOrthogonal@3.00/OR021@3_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOrthogonal@3.00/OR007@3_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR007_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR014_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR021_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR014@6_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR021@6_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR007@6_1.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B007_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B014_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B021_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOpposite@12.00/OR021@12_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOpposite@12.00/OR007@12_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOrthogonal@3.00/OR021@3_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOrthogonal@3.00/OR007@3_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR007_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR014_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR021_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR014@6_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR007@6_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR021@6_2.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B007_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B014_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/Ball/B021_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOpposite@12.00/OR021@12_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOpposite@12.00/OR007@12_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOrthogonal@3.00/OR021@3_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceOrthogonal@3.00/OR007@3_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR007_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR014_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/InnerRace/IR021_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR014@6_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR021@6_3.mat
#
# /content/drive/MyDrive/Praca dyplomowa/Data/48kDriveEndBearingFaultData/OuterRaceCentered@6.00/OR007@6_3.mat

# %%
data
# Out:
#                                                signal     label  load
# 0   [0.05319692307692307, 0.08866153846153846, 0.0...    Normal     0
# 1   [-0.111192, -0.08302892307692307, -0.042348923...      B007     0
# 2   [0.03984553846153846, 0.0897046153846154, 0.13...      B014     0
# 3   [0.17152399999999998, 0.326772, 0.491618666666...      B021     0
# 4   [0.051749333333333335, 0.05592266666666667, 0....  OR021@12     0
# 5   [0.328152, 0.24011630769230768, 0.153332307692...  OR007@12     0
# 6   [-0.06802533333333333, -0.27335333333333334, -...   OR021@3     0
# 7   [0.471888, 0.4418473846153846, 0.3515169230769...   OR007@3     0
# 8   [0.010016, -0.023788, -0.007929333333333333, 0...     IR007     0
# 9   [0.18195733333333333, 0.2032413333333333, 0.21...     IR014     0
# 10  [0.851568, 0.6287667692307692, 0.3158436923076...     IR021     0
# 11  [0.609156923076923, 0.6759138461538462, 0.7309...   OR014@6     0
# 12  [0.013354666666666666, -0.34555199999999997, -...   OR021@6     0
# 13  [0.8935106666666667, 0.58844, 0.15441333333333...   OR007@6     0
# 14  [0.046104, -0.03713353846153846, -0.0894959999...    Normal     1
# 15  [-0.04109723076923077, -0.046104, -0.028371692...      B007     1
# 16  [-0.46354338461538463, -0.4758516923076923, -0...      B014     1
# 17  [-0.06195876923076923, -0.03755076923076923, -...      B021     1
# 18  [-0.6593866666666667, -0.6293386666666667, -0....  OR021@12     1
# 19  [0.2422024615384615, 0.3456756923076923, 0.402...  OR007@12     1
# 20  [0.002504, -0.024205333333333332, -0.063434666...   OR021@3     1
# 21  [-0.04380923076923077, -0.07677046153846154, -...   OR007@3     1
# 22  [0.03212676923076923, 0.07823076923076923, 0.1...     IR007     1
# 23  [0.23782153846153845, 0.20444307692307692, 0.1...     IR014     1
# 24  [1.1210990769230769, 0.7833507692307693, 0.391...     IR021     1
# 25  [0.13330523076923076, 0.15249784615384615, 0.1...   OR014@6     1
# 26  [0.040064, 0.021701333333333333, -0.0208666666...   OR021@6     1
# 27  [0.08471866666666666, 0.6948599999999999, 1.15...   OR007@6     1
# 28  [0.046104, -0.03713353846153846, -0.0894959999...    Normal     2
# 29  [0.09992676923076924, 0.14164984615384615, 0.1...      B007     2
# 30  [0.06446215384615385, 0.09575446153846154, 0.1...      B014     2
# 31  [-0.20360861538461536, -0.2953993846153846, -0...      B021     2
# 32  [-0.03338666666666667, -0.032552, -0.024205333...  OR021@12     2
# 33  [-0.19693292307692306, -0.1449876923076923, -0...  OR007@12     2
# 34  [-1.8671493333333333, -2.180984, -2.1701333333...   OR021@3     2
# 35  [0.11724184615384614, 0.30436984615384616, 0.4...   OR007@3     2
# 36  [0.06133292307692308, -0.015646153846153844, -...     IR007     2
# 37  [0.16568133333333332, 0.116436, 0.0626, 0.0171...     IR014     2
# 38  [-0.3917796923076923, -0.3844781538461538, -0....     IR021     2
# 39  [-0.124752, -0.12913292307692306, -0.132053538...   OR014@6     2
# 40  [-0.967796, -1.7336026666666666, -2.226056, -2...   OR007@6     2
# 41  [-0.3447173333333333, -0.4323573333333333, -0....   OR021@6     2
# 42  [0.014603076923076923, 0.05444861538461539, 0....    Normal     3
# 43  [0.25305046153846156, 0.2574313846153846, 0.23...      B007     3
# 44  [-0.05277969230769231, -0.0070929230769230765,...      B014     3
# 45  [0.09930092307692308, 0.06613107692307692, 0.0...      B021     3
# 46  [0.032552, 0.03756, 0.03422133333333333, 0.030...  OR021@12     3
# 47  [0.16710092307692306, 0.15959076923076923, 0.1...  OR007@12     3
# 48  [1.5483066666666667, 1.5040693333333333, 1.083...   OR021@3     3
# 49  [0.14978584615384616, 0.18921415384615384, 0.1...   OR007@3     3
# 50  [0.45311261538461534, 0.385104, 0.235318153846...     IR007     3
# 51  [0.001252, -0.028378666666666667, -0.056339999...     IR014     3
# 52  [-0.3917796923076923, -0.3844781538461538, -0....     IR021     3
# 53  [-0.10409907692307692, -0.11578153846153846, -...   OR014@6     3
# 54  [-0.055088, -0.07678933333333333, -0.076789333...   OR021@6     3
# 55  [0.24330533333333332, 0.229116, 0.164846666666...   OR007@6     3

# %%
with open ('48kdrive-end_normalbaseline_loadsplit_data.pkl', 'wb') as f:
  pickle.dump(data, f)

# %% [markdown]
# ### Cropping all of the data to the shortest signal length

# %%
with open('48kdrive-end_normalbaseline_loadsplit_data.pkl', 'rb') as f:
    data = pickle.load(f)

min_len = data['signal'].apply(len).min()
data['cropped_signal'] = data['signal'].apply(lambda x: x[:min_len])

with open('48kdrive-end_normalbaseline_loadsplit_cropped_data.pkl', 'wb') as f:
  pickle.dump(data, f)
